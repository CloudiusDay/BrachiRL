# %%
# This notebook 1) finds the dynamic programing solution to the Brachistochrone problem 
# 2) compares it with the analytic solution
# 3) shows the advantage of using dynamic programming instead of solving the problem analytically

# In order to reproduce the analytical solution, I had run into two issues which I resolved after some tinkering
# 1) The discretize of the environment: the reward has to be calculated with special care (instead of a first order
# approximation of the continuous differential equation)
# 2) The sampling interval in x and y direction has to be in some ratio, which is very strange!

# %%
import numpy as np
import matplotlib.pyplot as plt
import importlib
from math import *

from IPython.display import Math



import Agents.Analytic as Analytic
import Agents.DP as DP



# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)
# %load_ext autoreload
# %autoreload 2

# %%
# Dynamic Programming (DP) Solution

# %%
agentDP1 = DP.Agent()
agentDP1.print_config()
# Out:
# delta_x =  0.5
# delta_y =  0.05
# range_x =  (0, 10)
# range_y =  (0, 10)
# S.shape =  (201, 21)

# %%
p0 = (0,0)
pT = (10, 3)

x,y,_ = agentDP1.run(pT)

plt.plot(x, y)
plt.axis('equal')
plt.gca().invert_yaxis()
plt.grid()

# %%
# Compare DP with the Analytic Solution

# %%
p0 = (0,0)
pT = (10, 3)

x,y = Analytic.agent(pT)    
plt.plot(x, y)
plt.axis('equal')
plt.gca().invert_yaxis()
plt.grid()

agentDP2 = DP.Agent(range_y = (0,10))
x,y,_ = agentDP2.run(pT)    
plt.plot(x, y)

# %%
# The advantage of using DP is that it allows us to add arbitrary constraint 
# without going through pages of derivation again to arrive at a new analytical solution.

# %%
agentDP3 = DP.Agent(circle=(3,3,2))
x,y,_ = agentDP3.run(pT)    
plt.plot(x, y)
plt.axis('equal')
plt.gca().invert_yaxis()
plt.grid()

x,y,_ = agentDP2.run(pT)
plt.plot(x, y)
